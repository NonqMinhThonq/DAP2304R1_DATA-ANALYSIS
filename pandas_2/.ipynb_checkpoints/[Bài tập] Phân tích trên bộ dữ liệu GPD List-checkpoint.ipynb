# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1,Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.

import pandas as pd
df = pd.read_csv(r"D:\DAP2304R1_DATA-ANALYSIS\pandas_2\DATA\GDPList.csv", encoding = 'iso-8859-1')
df
# Out:
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# 122       Vietnam           Asia                 122722
# 123         Yemen         Africa                  33675
# 124        Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB

# %%
# 2,Tính giá trị lớn nhất và nhỏ nhất của GDP.

print('gia tri GDP lon nhat la:', df['GDP (millions of US$)'].max())
print('gia tri GDP lon nho la:', df['GDP (millions of US$)'].min())
# Out:
# gia tri GDP lon nhat la: 15094025
# gia tri GDP lon nho la: 10600

# %%
# 3, Hãy cho biết xu hướng phân bố dữ liệu của GDP.

import matplotlib.pyplot as plt 

df.plot.scatter(x='Country', y='GDP (millions of US$)', c ="pink")
# Out:
# <AxesSubplot: xlabel='Country', ylabel='GDP (millions of US$)'>

# %%
# 4,Hãy cho biết châu lục nào xuất hiện nhiều nhất?

print('chau luc xuat hien nhieu nhat la:',df['Continent'].value_counts().idxmax())
# Out:
# chau luc xuat hien nhieu nhat la: Europe

# %%
# 5, Với mỗi châu lục hãy tính tổng GDP; trung bình cộng GDP. Hợp nhất 2 bảng này thành một bảng duy nhất gồm 3 thông tin: Tên châu lục; Tổng GDP; TBC GDP.

df1 =
# Out:
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# 122       Vietnam           Asia                 122722
# 123         Yemen         Africa                  33675
# 124        Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
df1 = df.pivot_table(index = 'Continent', columns = 'GDP (millions of US$)', aggfunc = 'sum')
