# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[100, 6, np.nan], 
                  [9, 5, 12], 
                  [np.nan, np.nan, np.nan], 
                  [-3, 4, -200],
                  [2, 0, 7]])
df
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 2    NaN  NaN    NaN
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0

# %%
df.isna().sum()
# Out:
# 0    1
# 1    1
# 2    2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# 0    1
# 1    1
# 2    2
# dtype: int64

# %%
df.notna()
# Out:
#        0      1      2
# 0   True   True  False
# 1   True   True   True
# 2  False  False  False
# 3   True   True   True
# 4   True   True   True

# %%
df.dropna()
# Out:
#      0    1      2
# 1  9.0  5.0   12.0
# 3 -3.0  4.0 -200.0
# 4  2.0  0.0    7.0

# %%
df = pd.DataFrame([[100, 6, np.nan], 
                  [9, 5, 12], 
                  [np.nan, 9, np.nan], 
                  [-3, 4, -200],
                  [2, 0, 7]])
df
# Out:
#        0  1      2
# 0  100.0  6    NaN
# 1    9.0  5   12.0
# 2    NaN  9    NaN
# 3   -3.0  4 -200.0
# 4    2.0  0    7.0

# %%
#xoas gia tri bi khuyet thieu(missing data) theo colums axis ='columns' or axis = 1

df.dropna(axis=1)
# Out:
#    1
# 0  6
# 1  5
# 2  9
# 3  4
# 4  0

# %%
df = pd.DataFrame([[100, 6, np.nan], 
                  [9, 5, 12], 
                  [np.nan, np.nan, np.nan], 
                  [-3, 4, -200],
                  [2, 0, 7],
                  [np.nan, np.nan,5]])
df
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 2    NaN  NaN    NaN
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    NaN  NaN    5.0

# %%
#Xoá các dòng chứa toàn các giá trị bị khuyết: dropna(how='all')

df.dropna(how = 'all')
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    NaN  NaN    5.0

# %%
 #dòng có ít nhất n giá trị bị khuyết: dropna(thresh=n)


df = pd.DataFrame([[100, 6, np.nan], 
                  [9, 5, 12], 
                  [np.nan, np.nan, np.nan], 
                  [-3, 4, -200],
                  [2, 0, 7],
                  [np.nan, np.nan,5]])
df
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 2    NaN  NaN    NaN
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    NaN  NaN    5.0

# %%
df.dropna(thresh=1)
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    NaN  NaN    5.0

# %%
df.dropna(subset=[0,1])
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0

# %%
df = pd.DataFrame([[100, 6, np.nan], 
                  [9, 5, 12], 
                  [np.nan, np.nan, np.nan], 
                  [-3, 4, -200],
                  [2, 0, 7],
                  [np.nan, np.nan,5]])
df
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 2    NaN  NaN    NaN
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    NaN  NaN    5.0

# %%
df.fillna(1)
# Out:
#        0    1      2
# 0  100.0  6.0    1.0
# 1    9.0  5.0   12.0
# 2    1.0  1.0    1.0
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    1.0  1.0    5.0

# %%
df.fillna(method = 'ffill')
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 2    9.0  5.0   12.0
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    2.0  0.0    5.0

# %%
df
# Out:
#        0    1      2
# 0  100.0  6.0    NaN
# 1    9.0  5.0   12.0
# 2    NaN  NaN    NaN
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    NaN  NaN    5.0

# %%
df.fillna(method = 'bfill')
# Out:
#        0    1      2
# 0  100.0  6.0   12.0
# 1    9.0  5.0   12.0
# 2   -3.0  4.0 -200.0
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    NaN  NaN    5.0

# %%
xac dinh ngoai lai

# %%
points = pd.DataFrame([[100, 6], 
                       [9, 5], 
                       [3, 5], 
                       [1,-200],
                       [2, 0], 
                       [3, -4], 
                       [-2, 5], 
                       [-1, -10]
                      ], columns = ['X', 'Y'])
points
# Out:
#      X    Y
# 0  100    6
# 1    9    5
# 2    3    5
# 3    1 -200
# 4    2    0
# 5    3   -4
# 6   -2    5
# 7   -1  -10

# %%
import matplotlib.pyplot as plt

points.plot.scatter(x='X', y = 'Y', c = 'black', marker ='*')
plt.xlabel('truc x')
plt.ylabel('truc y')
plt.title('sccatter plot')
# Out:
# Text(0.5, 1.0, 'sccatter plot')

# %%
df = df.fillna(0)
df
# Out:
#        0    1      2
# 0  100.0  6.0    0.0
# 1    9.0  5.0   12.0
# 2    0.0  0.0    0.0
# 3   -3.0  4.0 -200.0
# 4    2.0  0.0    7.0
# 5    0.0  0.0    5.0

# %%
from math import sqrt
c = df[0]
u = col1.mean()
s = 0
for i in c.values:
    s+= (i - u)**2
s = sqrt(s/col1.count())
z =[]
for i in col1.values:
    z.append((i - u)/s)
z
# Out:
# [2.224900907698982,
#  -0.24419644108891267,
#  -0.48839288217782534,
#  -0.5697916958741296,
#  -0.43412700638028917,
#  -0.48839288217782534]

# %%
from scipy import stats
z = stats.zscore(df)

z
# Out:
#           0         1         2
# 0  2.224901  1.364097  0.383760
# 1 -0.244196  0.974355  0.540753
# 2 -0.488393 -0.974355  0.383760
# 3 -0.569792  0.584613 -2.232787
# 4 -0.434127 -0.974355  0.475339
# 5 -0.488393 -0.974355  0.449174

# %%
zcore = df.apply(stats.zscore)
zcore
# Out:
#           0         1         2
# 0  2.224901  1.364097  0.383760
# 1 -0.244196  0.974355  0.540753
# 2 -0.488393 -0.974355  0.383760
# 3 -0.569792  0.584613 -2.232787
# 4 -0.434127 -0.974355  0.475339
# 5 -0.488393 -0.974355  0.449174

# %%
df.count().sum()
# Out:
# 18

# %%
noisy = np.where((z > 1.5) | (z < -1.5))
noisy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 noisy = np.where((z > 1.5) | (z < -1.5))
#       2 noisy
#
# TypeError: '>' not supported between instances of 'list' and 'float'
