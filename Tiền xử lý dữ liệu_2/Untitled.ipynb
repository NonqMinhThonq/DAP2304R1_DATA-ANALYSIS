# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %time
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
df = pd.read_csv(r"D:\DAP2304R1_DATA-ANALYSIS\visuallization_3\DATA\Credit_Scoring.csv")
df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                9                 0                              0.116951
# 1               10                 0                              0.189169
# 2               11                 0                              0.644226
# 3               12                 0                              0.018798
# 4               13                 0                              0.010352
# ...            ...               ...                                   ...
# 149987      149996                 0                              0.040674
# 149988      149997                 0                              0.299745
# 149989      149998                 0                              0.246044
# 149990      149999                 0                              0.000000
# 149991      150000                 0                              0.850283
#
# ...

# %%
df = df.rename(columns = {'RevolvingUtilizationOfUnsecuredLines':'total_money'})
df1 = df[['SeriousDlqin2yrs',
          'age',
          'total_money',
           'NumberOfTime30-59DaysPastDueNotWorse',
           'DebtRatio','MonthlyIncome',
           'NumberOfOpenCreditLinesAndLoans',
           'NumberOfTimes90DaysLate',
           'NumberRealEstateLoansOrLines',
           'NumberOfTime60-89DaysPastDueNotWorse',
           'NumberOfDependents' ]]
df1
# Out:
#         SeriousDlqin2yrs  age  total_money  \
# 0                      0   27     0.116951
# 1                      0   57     0.189169
# 2                      0   30     0.644226
# 3                      0   51     0.018798
# 4                      0   46     0.010352
# ...                  ...  ...          ...
# 149987                 0   74     0.040674
# 149988                 0   44     0.299745
# 149989                 0   58     0.246044
# 149990                 0   30     0.000000
# 149991                 0   64     0.850283
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          0    46.000000            NaN
# 1                                          0     0.606291        23684.0
# 2                                          0     0.309476         2500.0
# 3                                          0     0.531529         6501.0
# 4                                          0     0.298354        12454.0
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149992 entries, 0 to 149991
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SeriousDlqin2yrs                      149992 non-null  int64
#  1   total_money                           149992 non-null  float64
#  2   age                                   149992 non-null  int64
#  3   NumberOfTime30-59DaysPastDueNotWorse  149992 non-null  int64
#  4   DebtRatio                             149992 non-null  float64
#  5   MonthlyIncome                         120262 non-null  float64
#  6   NumberOfOpenCreditLinesAndLoans       149992 non-null  int64
#  7   NumberOfTimes90DaysLate               149992 non-null  int64
#  8   NumberRealEstateLoansOrLines          149992 non-null  int64
#  9   NumberOfTime60-89DaysPastDueNotWorse  149992 non-null  int64
# ...

# %%
# Out:
#        SeriousDlqin2yrs            age    total_money  \
# count     149992.000000  149992.000000  149992.000000
# mean           0.066837      52.295516       6.048729
# std            0.249740      14.771902     249.762028
# min            0.000000       0.000000       0.000000
# 25%            0.000000      41.000000       0.029863
# 50%            0.000000      52.000000       0.154162
# 75%            0.000000      63.000000       0.559012
# max            1.000000     109.000000   50708.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         149992.000000  149992.000000   1.202620e+05
# mean                               0.421029     352.985824   6.669872e+03
# std                                4.192890    2037.824499   1.438414e+04
# min                                0.000000       0.000000   0.000000e+00
# 25%                                0.000000       0.175075   3.400000e+03
# ...

# %%
# Nêu thông tin về kiểu dữ liệu và khoảng dữ liệu ở các cột
df1.describe()
# Out:
#        SeriousDlqin2yrs            age    total_money  \
# count     149992.000000  149992.000000  149992.000000
# mean           0.066837      52.295516       6.048729
# std            0.249740      14.771902     249.762028
# min            0.000000       0.000000       0.000000
# 25%            0.000000      41.000000       0.029863
# 50%            0.000000      52.000000       0.154162
# 75%            0.000000      63.000000       0.559012
# max            1.000000     109.000000   50708.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         149992.000000  149992.000000   1.202620e+05
# mean                               0.421029     352.985824   6.669872e+03
# std                                4.192890    2037.824499   1.438414e+04
# min                                0.000000       0.000000   0.000000e+00
# 25%                                0.000000       0.175075   3.400000e+03
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149992 entries, 0 to 149991
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SeriousDlqin2yrs                      149992 non-null  int64
#  1   age                                   149992 non-null  int64
#  2   total_money                           149992 non-null  float64
#  3   NumberOfTime30-59DaysPastDueNotWorse  149992 non-null  int64
#  4   DebtRatio                             149992 non-null  float64
#  5   MonthlyIncome                         120262 non-null  float64
#  6   NumberOfOpenCreditLinesAndLoans       149992 non-null  int64
#  7   NumberOfTimes90DaysLate               149992 non-null  int64
#  8   NumberRealEstateLoansOrLines          149992 non-null  int64
#  9   NumberOfTime60-89DaysPastDueNotWorse  149992 non-null  int64
# ...

# %%
# Kiểm tra dữ liệu khuyết thiếu
df1.isna().sum()
# Out:
# SeriousDlqin2yrs                            0
# age                                         0
# total_money                                 0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29730
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
missing = df1[df1.isnull().any(axis = 1)]
missing
# Out:
#         SeriousDlqin2yrs  age  total_money  \
# 0                      0   27     0.116951
# 8                      0   78     0.061086
# 24                     0   62     0.083418
# 33                     0   81     0.072898
# 44                     0   62     1.000000
# ...                  ...  ...          ...
# 149968                 0   76     0.000627
# 149969                 0   29     0.236450
# 149976                 0   84     0.037548
# 149984                 0   50     0.871976
# 149989                 0   58     0.246044
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                          0       46.0            NaN
# 8                                          0     2058.0            NaN
# 24                                         0      977.0            NaN
# 33                                         0       75.0            NaN
# 44                                         0        0.0            NaN
# ...

# %%
df2 = df1.dropna()

# %%
df2
# Out:
#         SeriousDlqin2yrs  age  total_money  \
# 1                      0   57     0.189169
# 2                      0   30     0.644226
# 3                      0   51     0.018798
# 4                      0   46     0.010352
# 5                      1   40     0.964673
# ...                  ...  ...          ...
# 149986                 0   50     0.385742
# 149987                 0   74     0.040674
# 149988                 0   44     0.299745
# 149990                 0   30     0.000000
# 149991                 0   64     0.850283
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                          0   0.606291        23684.0
# 2                                          0   0.309476         2500.0
# 3                                          0   0.531529         6501.0
# 4                                          0   0.298354        12454.0
# 5                                          3   0.382965        13700.0
# ...

# %%
df2.describe()
# Out:
#        SeriousDlqin2yrs            age    total_money  \
# count     120262.000000  120262.000000  120262.000000
# mean           0.069482      51.290158       5.900179
# std            0.254272      14.426680     257.048162
# min            0.000000       0.000000       0.000000
# 25%            0.000000      40.000000       0.035077
# 50%            0.000000      51.000000       0.177269
# 75%            0.000000      61.000000       0.579392
# max            1.000000     103.000000   50708.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         120262.000000  120262.000000   1.202620e+05
# mean                               0.381758      26.600312   6.669872e+03
# std                                3.499331     424.458762   1.438414e+04
# min                                0.000000       0.000000   0.000000e+00
# 25%                                0.000000       0.143402   3.400000e+03
# ...

# %%
df2.boxplot()
# Out:
# <Axes: >

# %%
plt.hist(df2.MonthlyIncome, bins = 10)
# Out:
# (array([1.20245e+05, 7.00000e+00, 6.00000e+00, 1.00000e+00, 0.00000e+00,
#         2.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([      0.,  300875.,  601750.,  902625., 1203500., 1504375.,
#         1805250., 2106125., 2407000., 2707875., 3008750.]),
#  <BarContainer object of 10 artists>)

# %%
df2[['MonthlyIncome']].describe()
# Out:
#        MonthlyIncome
# count   1.202620e+05
# mean    6.669872e+03
# std     1.438414e+04
# min     0.000000e+00
# 25%     3.400000e+03
# 50%     5.400000e+03
# 75%     8.249000e+03
# max     3.008750e+06

# %%
logic = ((target["gia_m2"]>=min_price) & (target["gia_m2"]<= max_price) & \
(target["mat_tien"]>=min_mat_tien) & (target["mat_tien"]<= max_mat_tien) & \
(target["dien_tich"]>=min_dt) & (target["dien_tich"]<= max_dt))

clean = target[logic]

# %%
def get_q1_q3(values):
    values = np.array(values)
    q1 = np.quantile(values, 0.25)
    q3 = np.quantile(values, 0.75)
    IQR = q3-q1 
    _min_value = q1 -  1.5*IQR 
    _max_value = q3 +  1.5*IQR 

    return _min_value, _max_value

# %%
min_m, max_m = get_q1_q3(df2['MonthlyIncome'])
# Out:
#         MonthlyIncome
# 1             23684.0
# 2              2500.0
# 3              6501.0
# 4             12454.0
# 5             13700.0
# ...               ...
# 149986         3400.0
# 149987         2100.0
# 149988         5584.0
# 149990         5716.0
# 149991         8158.0
#
# [120262 rows x 1 columns]

# %%
logic = ((df['MonthlyIncome'] >= min_m) & (df['MonthlyIncome'] <= max_m))

clean = df2[logic]
# Out:
# C:\Users\notho\AppData\Local\Temp\ipykernel_4208\1567218691.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clean = df2[logic]

# %%
clean
# Out:
#         SeriousDlqin2yrs  age  total_money  \
# 2                      0   30     0.644226
# 3                      0   51     0.018798
# 4                      0   46     0.010352
# 5                      1   40     0.964673
# 6                      0   76     0.019657
# ...                  ...  ...          ...
# 149986                 0   50     0.385742
# 149987                 0   74     0.040674
# 149988                 0   44     0.299745
# 149990                 0   30     0.000000
# 149991                 0   64     0.850283
#
#         NumberOfTime30-59DaysPastDueNotWorse   DebtRatio  MonthlyIncome  \
# 2                                          0    0.309476         2500.0
# 3                                          0    0.531529         6501.0
# 4                                          0    0.298354        12454.0
# 5                                          3    0.382965        13700.0
# 6                                          0  477.000000            0.0
# ...

# %%
# xu ly ngoai lai
min_price, max_price = get_Q1_Q3(target["gia_m2"])
# target = target[target["gia_m2"]>=min_price & target["gia_m2"]<= max_price]


min_mat_tien, max_mat_tien = get_Q1_Q3(target["mat_tien"])
# target = target[target["gia_m2"]>=min_price & target["gia_m2"]<= max_price]

min_dt, max_dt = get_Q1_Q3(target["dien_tich"])
# target = target[target["gia_m2"]>=min_price & target["gia_m2"]<= max_price]

# %%
sns.boxplot(x =clean['MonthlyIncome'])
# Out:
# <Axes: xlabel='MonthlyIncome'>

# %%
clean[['MonthlyIncome']].describe()
# Out:
#        MonthlyIncome
# count  115384.000000
# mean     5761.743864
# std      3282.568427
# min         0.000000
# 25%      3325.000000
# 50%      5200.000000
# 75%      7809.250000
# max     15520.000000

# %%
df2[['MonthlyIncome']].describe()
# Out:
#        MonthlyIncome
# count   1.202620e+05
# mean    6.669872e+03
# std     1.438414e+04
# min     0.000000e+00
# 25%     3.400000e+03
# 50%     5.400000e+03
# 75%     8.249000e+03
# max     3.008750e+06

# %%
df3 = df2[(df2['MonthlyIncome'] >= 1000) & (df2['MonthlyIncome'] <= 15000)]
df3
# Out:
#         SeriousDlqin2yrs  age  total_money  \
# 2                      0   30     0.644226
# 3                      0   51     0.018798
# 4                      0   46     0.010352
# 5                      1   40     0.964673
# 7                      0   64     0.548458
# ...                  ...  ...          ...
# 149986                 0   50     0.385742
# 149987                 0   74     0.040674
# 149988                 0   44     0.299745
# 149990                 0   30     0.000000
# 149991                 0   64     0.850283
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 2                                          0   0.309476         2500.0
# 3                                          0   0.531529         6501.0
# 4                                          0   0.298354        12454.0
# 5                                          3   0.382965        13700.0
# 7                                          0   0.209892        11362.0
# ...

# %%
bins = [0, 3000, 4000, 5000, 8000, 15000]
income_labels = ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5']

# %%
df3['new'] = pd.cut(df3['MonthlyIncome'], bins = bins, labels = income_labels)
df3
# Out:
# C:\Users\notho\AppData\Local\Temp\ipykernel_4208\2556326607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['new'] = pd.cut(df3['MonthlyIncome'], bins = bins, labels = income_labels)
#         SeriousDlqin2yrs  age  total_money  \
# 2                      0   30     0.644226
# 3                      0   51     0.018798
# 4                      0   46     0.010352
# 5                      1   40     0.964673
# 7                      0   64     0.548458
# ...                  ...  ...          ...
# 149986                 0   50     0.385742
# 149987                 0   74     0.040674
# 149988                 0   44     0.299745
# 149990                 0   30     0.000000
# 149991                 0   64     0.850283
#
# ...

# %%
df3['new'].value_counts()
# Out:
# Group 4    32959
# Group 5    26166
# Group 1    20655
# Group 3    15461
# Group 2    15310
# Name: new, dtype: int64
