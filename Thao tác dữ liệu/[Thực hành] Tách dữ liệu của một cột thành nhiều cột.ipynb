# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"D:\DAP2304R1_DATA-ANALYSIS\Thao tác dữ liệu\DATA\shopeep_koreantop_clothing_shop_data.csv")
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
# Để đơn giản ta thực hiện lọc tập dữ liệu ban đầu theo các thuộc tính sau
df = df[['date_collected','shop_location','response_time']]
df
# Out:
#     date_collected               shop_location response_time
# 0       2021-06-13                         NaN      10:13:55
# 1       2021-06-13    San Nicolas,Metro Manila      10:43:05
# 2       2021-06-13     Pasay City,Metro Manila      08:32:07
# 3       2021-06-13        Binondo,Metro Manila      09:10:38
# 4       2021-06-13  Caloocan City,Metro Manila      11:40:59
# ..             ...                         ...           ...
# 741     2021-07-06          Legazpi City,Albay      08:45:30
# 742     2021-07-06                         NaN      08:01:23
# 743     2021-07-06                         NaN      08:46:30
# 744     2021-07-06        Binondo,Metro Manila      12:19:44
# 745     2021-07-06     Pasay City,Metro Manila      10:02:42
#
# [746 rows x 3 columns]

# %%
# 2. Tách cột dữ liệu có kiểu chuỗiTa có thể sử dụng các phép toán tách chuỗi splitHàm str.split(‘Ký tự phân cách’) có tác dụng tách chuỗi ban đầu str thành các chuỗi con được ngăn cách nhau bởi ký tự phân cách


# Tách cột shop_location thành 2 cột District và City

df['District']=df['shop_location'].str.split(',').str[0]
df['City']=df['shop_location'].str.split(',').str[1]
df
# Out:
# C:\Users\notho\AppData\Local\Temp\ipykernel_10604\2338400551.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['District']=df['shop_location'].str.split(',').str[0]
# C:\Users\notho\AppData\Local\Temp\ipykernel_10604\2338400551.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City']=df['shop_location'].str.split(',').str[1]
#     date_collected               shop_location response_time       District  \
# ...

# %%
#2. Tách cột dữ liệu có kiểu chuỗiTa có thể sử dụng các phép toán tách chuỗi splitHàm str.split(‘Ký tự phân cách’) có tác dụng tách chuỗi ban đầu str thành các chuỗi con được ngăn cách nhau bởi ký tự phân cách


# Tách cột shop_location thành 2 cột District và City

df['District'] = df['shop_location'].str.split(',').str[0]
df['City'] =df ['shop_location'].str.split(',').str[1]
df
# Out:
# C:\Users\notho\AppData\Local\Temp\ipykernel_10604\2168014212.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['District'] = df['shop_location'].str.split(',').str[0]
# C:\Users\notho\AppData\Local\Temp\ipykernel_10604\2168014212.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'] =df ['shop_location'].str.split(',').str[1]
#     date_collected               shop_location response_time       District  \
# ...

# %%
df['rate category'] = df.apply(lambda x: udf(x['rating_good']), axis = 1)

# %%
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
print(df['rate category'].value_counts(ascending=True))
# Out:
# g       56
# b      159
# v g    531
# Name: rate category, dtype: int64

# %%
df1 = df.groupby(['rate category']).count()
df1
# Out:
#                pk_shop  date_collected  shopid  name  join_month  join_day  \
# rate category
# b                  159             159     159   159         159       159
# g                   56              56      56    56          56        56
# v g                531             531     531   531         531       531
#
#                join_year  item_count  follower_count  response_time  \
# rate category
# b                    159         159             159            159
# g                     56          56              56             56
# v g                  531         531             531            531
#
#                response_rate  shop_location  rating_bad  rating_good  \
# rate category
# b                        159             60         159          159
# g                         56             30          56           56
# v g                      531            338         531          531
#
# ...

# %%
df2 = df1/df1.shape[0]
df2
# Out:
#                   pk_shop  date_collected      shopid        name  join_month  \
# rate category
# b               53.000000       53.000000   53.000000   53.000000   53.000000
# g               18.666667       18.666667   18.666667   18.666667   18.666667
# v g            177.000000      177.000000  177.000000  177.000000  177.000000
#
#                  join_day   join_year  item_count  follower_count  \
# rate category
# b               53.000000   53.000000   53.000000       53.000000
# g               18.666667   18.666667   18.666667       18.666667
# v g            177.000000  177.000000  177.000000      177.000000
#
#                response_time  response_rate  shop_location  rating_bad  \
# rate category
# b                  53.000000      53.000000      20.000000   53.000000
# g                  18.666667      18.666667      10.000000   18.666667
# v g               177.000000     177.000000     112.666667  177.000000
#
# ...

# %%
length = df1.shape[0]

# %%
d2 = df1/length
d2
# Out:
#                   pk_shop  date_collected      shopid        name  join_month  \
# rate category
# b               53.000000       53.000000   53.000000   53.000000   53.000000
# g               18.666667       18.666667   18.666667   18.666667   18.666667
# v g            177.000000      177.000000  177.000000  177.000000  177.000000
#
#                  join_day   join_year  item_count  follower_count  \
# rate category
# b               53.000000   53.000000   53.000000       53.000000
# g               18.666667   18.666667   18.666667       18.666667
# v g            177.000000  177.000000  177.000000      177.000000
#
#                response_time  response_rate  shop_location  rating_bad  \
# rate category
# b                  53.000000      53.000000      20.000000   53.000000
# g                  18.666667      18.666667      10.000000   18.666667
# v g               177.000000     177.000000     112.666667  177.000000
#
# ...

# %%
df = pd.read_csv("data\shopeep_koreantop_clothing_shop_data.csv")
# 1. tao 1 cot moi/  rategood > 1k ==>very good , 500 -- 999: good, else : bad

# 2. tinh tong cac cateogty do sao cho / verified =1

# 3. % vs phan 2 


#print(df.head)
conditions = [(df['rating_good']>=1000),(df['rating_good']>=500)&(df['rating_good']<=999),(df['rating_good']<500)]
choices =['very good','good','bad']
df['Rate category'] = np.select(conditions,choices)
#print(df)

def udf(value):
    if value>1000:
        return "very good"
    elif value >=500 and value <=999:
        return "good"
    return "bad"
#
df["Rate category"] = df.apply(lambda x:udf(x["rating_good"]),axis=1)


#2 
# b21: toi can lay tat cung rc sao no t/m is_shopee_verified =1 
df_1 = df[(df['is_shopee_verified']==1)]

length = df_1.shape[0]
# b22: thuc hien thong ke
df_1 = df_1.groupby(['Rate category'])['Rate category'].count()

# % verify

df_2 = df_1 / length
print(df_2)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"D:\DAP2304R1_DATA-ANALYSIS\Thao tác dữ liệu\DATA\shopeep_koreantop_clothing_shop_data.csv")
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
df1 = df[['shop_location']]
df1
# Out:
#                   shop_location
# 0                           NaN
# 1      San Nicolas,Metro Manila
# 2       Pasay City,Metro Manila
# 3          Binondo,Metro Manila
# 4    Caloocan City,Metro Manila
# ..                          ...
# 741          Legazpi City,Albay
# 742                         NaN
# 743                         NaN
# 744        Binondo,Metro Manila
# 745     Pasay City,Metro Manila
#
# [746 rows x 1 columns]

# %%
df1['city'] = df1[]

# %%
str(np.nan)
# Out:
# 'nan'

# %%
def udf(value, index):
    try:
        if pd.isna(value):
            return -1
        return value.split(',')[index]
    except Exeption as e:
        logging. info(e)
        return -1

# %%
df['city'] = df['shop_location'].apply(lambda x: udf(x,0))
df["district"] = df["shop_location"].apply(lambda x: udf(x,1))
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
df[['a','b']] = df['shop_location'].str.split(',', expand = True)
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...
